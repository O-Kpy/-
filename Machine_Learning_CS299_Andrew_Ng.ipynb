# %% [markdown]
# <a href="https://colab.research.google.com/github/O-Kpy/Machine-Learning-Lectures/blob/main/Machine_Learning_CS299_Andrew_Ng.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1강. Welcome to ML
#
# 1. 지도 학습(Supervised Learning)
#  > 회귀, 분류...가 지도 학습이다.(SVM, Regression, Classifier, 인공지능 모델, 트리모델, 시계열모델... 등등)
#
#  > X(변수 피쳐)들과 Y(레이블피쳐)가 주어지고, 주로 예측을 하는데 그 목적이 있다.
#
# 2. 비지도 학습(Unsupervised Learning)
#  > 군집화, 차원축소분석(LCA빼고, PCA, ICA, SVD...), SNA(소셜 네트워크 분석)... 등등
#
#  > X가 주어지고, 유사성, 관련성이 있는 데이터들 끼리 군집을 이룹니다. 이 군집을 통해 구조를 만들고 분류 하여 데이터의 인사이트를 얻고자 하는 것이 주 목표이다. ==> 데이터 마이닝의 성격이 강하다.
#
#  > ex) 구글의 비슷한 뉴스를 모아서 보여주는 알고리즘
#
#  ![다운로드.png](data:image/png;base64,...)
#
# 3. 강화 학습(Reinforcement Learning)
#  > 행동 집합(Action), 환경 상태 집합(State), 보상 집합(Reward)로 구성되어 있다.
#
#  > "잘했으면 상을 주고, 못했으면 벌을 주는..."
#
#  > 최적의 방법이 무엇인지 아무것도 모를때, 시간이 지남에 따라 나아지고 불량률도 적어진다.
# ![Screen_Shot_2017-07-25_at_1.20.52_PM.png](data:image/png;base64,...)

# %% [markdown]
# # 2강 Linear Regression and Gradient Descent
# * Linear Regression
#  > X=input, Y=output
# ![2018110823556_6_1280.png](data:image/png;base64,...)
#
# * 예측값과 실제 값의 차이가 최소가 되도록 하는 알고리즘(최소제곱법)
#
# * Gradient Descent(경사하강법)
#  > 손실함수의 최적값을 찾기 위함
#
# ![dsBuffer.bmp.png](data:image/png;base64,...)
#
#  > 확률적 경사 하강법(SGD) - 비효율적이지만 글로벌 최적값으로
#  수렴해 간다.(계산이 빠르다, 데이터가 큰 상황에서 BGD보다 자주 쓰인다.)
#
#  > BGD(Batch Gradient Descent) - 효율적이지만 계산이 느리다
# ![다운로드.png](data:image/png;base64,...)
#
#  * Learning Late는 여러 값을 시도해야한다.(튜닝)
#   > Learning late가 작을경우 : 걸음 걸음이 작다 ==> 계산시간이 많다.
#   > Learning late가 클 경우 : 최적값까지 갈 걸음걸음이 크다 ==> 계산시간이 짧지만 cost function이 높아서 결과가 안좋다.

# %% [markdown]
# # 3강 Locally Weighted & Logistic Regression
#
# * Locally Weighted regression
#  > Linear Regression에서 해결 하지 못하는 **비선형적 방식을 해결**하는 방법중 하나
#
# ![4.png](data:image/png;base64,...)
#
#  >  각각의 포인트에 대해 거리에 대한 가중치를 줘서 만든 linear regression을 이어 붙인다.
#
#  > 가중치를 부여하는 알고리즘이 커널을 이용해서 거리가 가까우면 가중치를 높게주는 형식
#
#
# * Logistic Regression
#  > 분류 (Classification, Binary, {0,1}로 분류, g(z))
#
#  ![Log1.png](data:image/png;base64,...)
#  > 위의 Linear 모델로는 해결할 수 없기 때문에 Logistic 사용
#
#  ![vlcsnap-2015-02-10-20h41m20s58.png](data:image/png;base64,...)
#  > sigmoid와 logistic은 같음
#
#  > 나중에 배우겠지만 비선형 경계도 가능하다. 각각의 경우에서 일단 하나의 클래스를 선택한 다음 나머지 모두를 하나로 묶는 방법으로 바이너리 분류를 만든다. 이러한 binary logistic regression  작업을 각각의 경우에서 반복한다.
#
#  ![252DC245586BA7330D.png](data:image/png;base64,...)
